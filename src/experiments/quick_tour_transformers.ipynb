# %%
from transformers import pipeline
classifier = pipeline(task='sentiment-analysis')
# Out:
# 2023-01-08 13:09:33.778275: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-08 13:09:33.921303: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/lib64:/usr/lib/cuda/include:
# 2023-01-08 13:09:33.921324: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-08 13:09:33.949860: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-01-08 13:09:34.629772: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/lib64:/usr/lib/cuda/include:
# 2023-01-08 13:09:34.630043: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib/cuda/lib64:/usr/lib/cuda/include:
# 2023-01-08 13:09:34.630051: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
sentence = "We are happy to use transformer"
classifier(sentence)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998452663421631}]

# %% [markdown]
# ### Pipeline batching

# %%
from transformers.pipelines.pt_utils import KeyDataset
import datasets
dataset = datasets.load_dataset("imdb", name="plain_text",split="unsupervised")
for out in classifier(KeyDataset(dataset,"text"), batch_size=8, truncation = "only_first"):
    print(out)
# Out:
# Downloading builder script:   0%|          | 0.00/4.31k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.17k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.59k [00:00<?, ?B/s]
# Downloading and preparing dataset imdb/plain_text to /home/minh-hieu-do/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1...
# Downloading data:   0%|          | 0.00/84.1M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Disabling tokenizer parallelism, we're using DataLoader multithreading already
# Dataset imdb downloaded and prepared to /home/minh-hieu-do/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1. Subsequent calls will reuse this data.
# {'label': 'POSITIVE', 'score': 0.5735189914703369}
# {'label': 'POSITIVE', 'score': 0.9997995495796204}
# {'label': 'POSITIVE', 'score': 0.9996894598007202}
# {'label': 'NEGATIVE', 'score': 0.9103311896324158}
# {'label': 'NEGATIVE', 'score': 0.9979425072669983}
# {'label': 'NEGATIVE', 'score': 0.9977090358734131}
# {'label': 'POSITIVE', 'score': 0.9988546371459961}
# {'label': 'POSITIVE', 'score': 0.9998350143432617}
# {'label': 'POSITIVE', 'score': 0.986367404460907}
# {'label': 'POSITIVE', 'score': 0.9990979433059692}
# {'label': 'NEGATIVE', 'score': 0.9988611936569214}
# {'label': 'NEGATIVE', 'score': 0.7546892762184143}
# {'label': 'POSITIVE', 'score': 0.9954826831817627}
# {'label': 'POSITIVE', 'score': 0.9992594122886658}
# {'label': 'POSITIVE', 'score': 0.9948545694351196}
# {'label': 'NEGATIVE', 'score': 0.9996827840805054}
# {'label': 'POSITIVE', 'score': 0.999333918094635}
# {'label': 'NEGATIVE', 'score': 0.724955141544342}
# {'label': 'POSITIVE', 'score': 0.8955302238464355}
# {'label': 'POSITIVE', 'score': 0.9941614270210266}
# {'label': 'NEGATIVE', 'score': 0.9993002414703369}
# {'label': 'POSITIVE', 'score': 0.9932733774185181}
# {'label': 'POSITIVE', 'score': 0.9977446794509888}
# {'label': 'NEGATIVE', 'score': 0.9934247732162476}
# {'label': 'POSITIVE', 'score': 0.7540916800498962}
# {'label': 'POSITIVE', 'score': 0.9969323873519897}
# {'label': 'NEGATIVE', 'score': 0.9975661039352417}
# {'label': 'NEGATIVE', 'score': 0.9986681938171387}
# {'label': 'POSITIVE', 'score': 0.9996500015258789}
# {'label': 'NEGATIVE', 'score': 0.9997075200080872}
# {'label': 'NEGATIVE', 'score': 0.9869158267974854}
# {'label': 'NEGATIVE', 'score': 0.984636664390564}
# {'label': 'NEGATIVE', 'score': 0.9993927478790283}
# {'label': 'POSITIVE', 'score': 0.9993690848350525}
# {'label': 'POSITIVE', 'score': 0.9938533306121826}
# {'label': 'POSITIVE', 'score': 0.9985712766647339}
# {'label': 'NEGATIVE', 'score': 0.9964244961738586}
# {'label': 'NEGATIVE', 'score': 0.9978469610214233}
# {'label': 'POSITIVE', 'score': 0.6149927973747253}
# {'label': 'POSITIVE', 'score': 0.9340106844902039}
# {'label': 'POSITIVE', 'score': 0.9993835687637329}
# {'label': 'POSITIVE', 'score': 0.9978803396224976}
# {'label': 'NEGATIVE', 'score': 0.9979458451271057}
# {'label': 'POSITIVE', 'score': 0.8828797936439514}
# {'label': 'NEGATIVE', 'score': 0.998021125793457}
# {'label': 'NEGATIVE', 'score': 0.996313750743866}
# {'label': 'NEGATIVE', 'score': 0.9680745601654053}
# {'label': 'NEGATIVE', 'score': 0.9982329607009888}
# {'label': 'POSITIVE', 'score': 0.9903361797332764}
# {'label': 'POSITIVE', 'score': 0.99179607629776}
# {'label': 'NEGATIVE', 'score': 0.9997889399528503}
# {'label': 'NEGATIVE', 'score': 0.9992750287055969}
# {'label': 'NEGATIVE', 'score': 0.9976535439491272}
# {'label': 'POSITIVE', 'score': 0.9996069073677063}
# {'label': 'POSITIVE', 'score': 0.9987795948982239}
# {'label': 'POSITIVE', 'score': 0.9994959831237793}
# {'label': 'NEGATIVE', 'score': 0.9263115525245667}
# {'label': 'NEGATIVE', 'score': 0.99679034948349}
# {'label': 'NEGATIVE', 'score': 0.9263115525245667}
# {'label': 'NEGATIVE', 'score': 0.9966811537742615}
# {'label': 'NEGATIVE', 'score': 0.9995488524436951}
# {'label': 'POSITIVE', 'score': 0.9990739822387695}
# {'label': 'POSITIVE', 'score': 0.9995629191398621}
# {'label': 'POSITIVE', 'score': 0.9996898174285889}
# {'label': 'POSITIVE', 'score': 0.9982253909111023}
# {'label': 'NEGATIVE', 'score': 0.9612616896629333}
# {'label': 'NEGATIVE', 'score': 0.6094610095024109}
# {'label': 'NEGATIVE', 'score': 0.9588566422462463}
# {'label': 'POSITIVE', 'score': 0.9992044568061829}
# {'label': 'POSITIVE', 'score': 0.9997866749763489}
# {'label': 'POSITIVE', 'score': 0.999524712562561}
# {'label': 'POSITIVE', 'score': 0.9984355568885803}
# {'label': 'NEGATIVE', 'score': 0.9880440831184387}
# {'label': 'POSITIVE', 'score': 0.9892014265060425}
# {'label': 'POSITIVE', 'score': 0.9993494153022766}
# {'label': 'POSITIVE', 'score': 0.9996987581253052}
# {'label': 'POSITIVE', 'score': 0.9930338859558105}
# {'label': 'POSITIVE', 'score': 0.9530155658721924}
# {'label': 'NEGATIVE', 'score': 0.806278645992279}
# {'label': 'POSITIVE', 'score': 0.9996961355209351}
# {'label': 'POSITIVE', 'score': 0.9974238872528076}
# {'label': 'POSITIVE', 'score': 0.9997324347496033}
# {'label': 'POSITIVE', 'score': 0.9939298629760742}
# {'label': 'NEGATIVE', 'score': 0.9994994401931763}
# {'label': 'NEGATIVE', 'score': 0.9994567036628723}
# {'label': 'POSITIVE', 'score': 0.7889978885650635}
# {'label': 'NEGATIVE', 'score': 0.9446483850479126}
# {'label': 'POSITIVE', 'score': 0.6171392202377319}
# {'label': 'POSITIVE', 'score': 0.9966063499450684}
# {'label': 'POSITIVE', 'score': 0.9538251757621765}
# {'label': 'POSITIVE', 'score': 0.995265007019043}
# {'label': 'POSITIVE', 'score': 0.9875401258468628}
# {'label': 'POSITIVE', 'score': 0.9988129138946533}
# {'label': 'POSITIVE', 'score': 0.9983310103416443}
# {'label': 'NEGATIVE', 'score': 0.7298833727836609}
# {'label': 'POSITIVE', 'score': 0.9925522804260254}
# {'label': 'POSITIVE', 'score': 0.999580442905426}
# {'label': 'POSITIVE', 'score': 0.997595489025116}
# {'label': 'NEGATIVE', 'score': 0.9863306283950806}
# {'label': 'POSITIVE', 'score': 0.8814720511436462}
# {'label': 'NEGATIVE', 'score': 0.9997345805168152}
# {'label': 'NEGATIVE', 'score': 0.9993864297866821}
# {'label': 'NEGATIVE', 'score': 0.6750675439834595}
# {'label': 'NEGATIVE', 'score': 0.999487042427063}
# {'label': 'NEGATIVE', 'score': 0.9841712117195129}
# {'label': 'POSITIVE', 'score': 0.9993269443511963}
# {'label': 'POSITIVE', 'score': 0.9803460240364075}
# {'label': 'NEGATIVE', 'score': 0.9849123954772949}
# {'label': 'POSITIVE', 'score': 0.9844229817390442}
# {'label': 'POSITIVE', 'score': 0.9978098273277283}
# {'label': 'POSITIVE', 'score': 0.9253382682800293}
# {'label': 'POSITIVE', 'score': 0.9891924262046814}
# {'label': 'POSITIVE', 'score': 0.8680174350738525}
# {'label': 'POSITIVE', 'score': 0.9977194666862488}
# {'label': 'POSITIVE', 'score': 0.9489954113960266}
# {'label': 'NEGATIVE', 'score': 0.9736310839653015}
# {'label': 'POSITIVE', 'score': 0.9994611144065857}
# {'label': 'POSITIVE', 'score': 0.9959701299667358}
# {'label': 'POSITIVE', 'score': 0.9993323683738708}
# {'label': 'POSITIVE', 'score': 0.9994751811027527}
# {'label': 'POSITIVE', 'score': 0.9996008276939392}
# {'label': 'POSITIVE', 'score': 0.9992111921310425}
# {'label': 'POSITIVE', 'score': 0.9978669285774231}
# {'label': 'POSITIVE', 'score': 0.9991388320922852}
# {'label': 'POSITIVE', 'score': 0.9980587363243103}
# {'label': 'POSITIVE', 'score': 0.933698832988739}
# {'label': 'POSITIVE', 'score': 0.9976460337638855}
# {'label': 'NEGATIVE', 'score': 0.97651606798172}
# {'label': 'POSITIVE', 'score': 0.9993942975997925}
# {'label': 'NEGATIVE', 'score': 0.9884584546089172}
# {'label': 'NEGATIVE', 'score': 0.9862323999404907}
# {'label': 'POSITIVE', 'score': 0.9955364465713501}
# {'label': 'POSITIVE', 'score': 0.9984545707702637}
# {'label': 'POSITIVE', 'score': 0.9663528800010681}
# {'label': 'POSITIVE', 'score': 0.9998457431793213}
# {'label': 'POSITIVE', 'score': 0.9998799562454224}
# {'label': 'POSITIVE', 'score': 0.9992544054985046}
# {'label': 'POSITIVE', 'score': 0.9998434782028198}
# {'label': 'NEGATIVE', 'score': 0.999739944934845}
# {'label': 'NEGATIVE', 'score': 0.9996557235717773}
# {'label': 'POSITIVE', 'score': 0.9983546137809753}
# {'label': 'POSITIVE', 'score': 0.9973892569541931}
# {'label': 'POSITIVE', 'score': 0.9804217219352722}
# {'label': 'POSITIVE', 'score': 0.9995653033256531}
# {'label': 'POSITIVE', 'score': 0.9990032315254211}
# {'label': 'POSITIVE', 'score': 0.9963821172714233}
# {'label': 'NEGATIVE', 'score': 0.9922279715538025}
# {'label': 'POSITIVE', 'score': 0.9982665777206421}
# {'label': 'POSITIVE', 'score': 0.9996641874313354}
# {'label': 'POSITIVE', 'score': 0.9987442493438721}
# {'label': 'POSITIVE', 'score': 0.9991139769554138}
# {'label': 'POSITIVE', 'score': 0.998819887638092}
# {'label': 'POSITIVE', 'score': 0.9997217059135437}
# {'label': 'POSITIVE', 'score': 0.9996422529220581}
# {'label': 'POSITIVE', 'score': 0.9957232475280762}
# {'label': 'POSITIVE', 'score': 0.9997689127922058}
# {'label': 'POSITIVE', 'score': 0.9988149404525757}
# {'label': 'POSITIVE', 'score': 0.99687260389328}
# {'label': 'POSITIVE', 'score': 0.9989408850669861}
# {'label': 'POSITIVE', 'score': 0.9993851184844971}
# {'label': 'POSITIVE', 'score': 0.999742329120636}
# {'label': 'POSITIVE', 'score': 0.9995761513710022}
# {'label': 'NEGATIVE', 'score': 0.9881327748298645}
# {'label': 'NEGATIVE', 'score': 0.9438666105270386}
# {'label': 'NEGATIVE', 'score': 0.9854200482368469}
# {'label': 'POSITIVE', 'score': 0.9867841005325317}
# {'label': 'NEGATIVE', 'score': 0.9213337898254395}
# {'label': 'POSITIVE', 'score': 0.999394416809082}
# {'label': 'POSITIVE', 'score': 0.9942610263824463}
# {'label': 'POSITIVE', 'score': 0.9992203712463379}
# {'label': 'POSITIVE', 'score': 0.8846915364265442}
# {'label': 'NEGATIVE', 'score': 0.603872537612915}
# {'label': 'POSITIVE', 'score': 0.9881078600883484}
# {'label': 'NEGATIVE', 'score': 0.6471260190010071}
# {'label': 'POSITIVE', 'score': 0.9888262748718262}
# {'label': 'POSITIVE', 'score': 0.9995273351669312}
# {'label': 'NEGATIVE', 'score': 0.9992190599441528}
# {'label': 'NEGATIVE', 'score': 0.9903631806373596}
# {'label': 'POSITIVE', 'score': 0.9994156360626221}
# {'label': 'POSITIVE', 'score': 0.9992839694023132}
# {'label': 'POSITIVE', 'score': 0.9994435906410217}
# {'label': 'POSITIVE', 'score': 0.9963685274124146}
# {'label': 'POSITIVE', 'score': 0.9920166730880737}
# {'label': 'POSITIVE', 'score': 0.9983677268028259}
# {'label': 'POSITIVE', 'score': 0.9991540908813477}
# {'label': 'POSITIVE', 'score': 0.9998220801353455}
# {'label': 'POSITIVE', 'score': 0.9988325238227844}
# {'label': 'POSITIVE', 'score': 0.9994717240333557}
# {'label': 'NEGATIVE', 'score': 0.9865917563438416}
# {'label': 'POSITIVE', 'score': 0.921143114566803}
# {'label': 'POSITIVE', 'score': 0.9998207688331604}
# {'label': 'NEGATIVE', 'score': 0.9594058394432068}
# {'label': 'NEGATIVE', 'score': 0.9993969202041626}
# {'label': 'NEGATIVE', 'score': 0.9994736313819885}
# {'label': 'POSITIVE', 'score': 0.9278398752212524}
# {'label': 'NEGATIVE', 'score': 0.957433819770813}
# {'label': 'POSITIVE', 'score': 0.9683749675750732}
# {'label': 'POSITIVE', 'score': 0.9995637536048889}
# {'label': 'POSITIVE', 'score': 0.9997290968894958}
# {'label': 'POSITIVE', 'score': 0.9974340796470642}
# {'label': 'POSITIVE', 'score': 0.9989635944366455}
# {'label': 'POSITIVE', 'score': 0.999521017074585}
# {'label': 'POSITIVE', 'score': 0.9188091158866882}
# {'label': 'POSITIVE', 'score': 0.9983004927635193}
# {'label': 'POSITIVE', 'score': 0.9998905658721924}
# {'label': 'POSITIVE', 'score': 0.9998195767402649}
# {'label': 'POSITIVE', 'score': 0.9740197658538818}
# {'label': 'POSITIVE', 'score': 0.9995280504226685}
# {'label': 'POSITIVE', 'score': 0.999745786190033}
# {'label': 'POSITIVE', 'score': 0.9979397654533386}
# {'label': 'POSITIVE', 'score': 0.851365327835083}
# {'label': 'POSITIVE', 'score': 0.997603714466095}
# {'label': 'POSITIVE', 'score': 0.999826967716217}
# {'label': 'NEGATIVE', 'score': 0.9964469075202942}
# {'label': 'POSITIVE', 'score': 0.9996439218521118}
# {'label': 'POSITIVE', 'score': 0.9997548460960388}
# {'label': 'NEGATIVE', 'score': 0.7007668614387512}
# {'label': 'POSITIVE', 'score': 0.9963757395744324}
# {'label': 'POSITIVE', 'score': 0.9995961785316467}
# {'label': 'POSITIVE', 'score': 0.9998538494110107}
# {'label': 'POSITIVE', 'score': 0.9996114373207092}
# {'label': 'POSITIVE', 'score': 0.9722384214401245}
# {'label': 'POSITIVE', 'score': 0.9993271827697754}
# {'label': 'NEGATIVE', 'score': 0.5580980181694031}
# {'label': 'POSITIVE', 'score': 0.9700305461883545}
# {'label': 'POSITIVE', 'score': 0.9994922876358032}
# {'label': 'NEGATIVE', 'score': 0.9653783440589905}
# {'label': 'POSITIVE', 'score': 0.9965567588806152}
# {'label': 'POSITIVE', 'score': 0.966414213180542}
# {'label': 'NEGATIVE', 'score': 0.9992089867591858}
# {'label': 'POSITIVE', 'score': 0.9969748258590698}
# {'label': 'NEGATIVE', 'score': 0.8854391574859619}
# {'label': 'NEGATIVE', 'score': 0.5299763083457947}
# {'label': 'POSITIVE', 'score': 0.9952377080917358}
# {'label': 'POSITIVE', 'score': 0.9856767654418945}
# {'label': 'POSITIVE', 'score': 0.9997486472129822}
# {'label': 'POSITIVE', 'score': 0.9995469450950623}
# {'label': 'POSITIVE', 'score': 0.9991686344146729}
# {'label': 'POSITIVE', 'score': 0.9995394945144653}
# {'label': 'POSITIVE', 'score': 0.9992371797561646}
# {'label': 'POSITIVE', 'score': 0.9996860027313232}
# {'label': 'POSITIVE', 'score': 0.9897915124893188}
# {'label': 'POSITIVE', 'score': 0.9957337975502014}
# {'label': 'POSITIVE', 'score': 0.8882476091384888}
# {'label': 'NEGATIVE', 'score': 0.8450291752815247}
# {'label': 'POSITIVE', 'score': 0.995215892791748}
# {'label': 'POSITIVE', 'score': 0.9986374974250793}
# {'label': 'NEGATIVE', 'score': 0.5680446028709412}
# {'label': 'NEGATIVE', 'score': 0.8179478645324707}
# {'label': 'POSITIVE', 'score': 0.999586284160614}
# {'label': 'POSITIVE', 'score': 0.9996278285980225}
# {'label': 'POSITIVE', 'score': 0.9953271150588989}
# {'label': 'NEGATIVE', 'score': 0.9986685514450073}
# {'label': 'POSITIVE', 'score': 0.9990624785423279}
# {'label': 'POSITIVE', 'score': 0.9995260238647461}
# {'label': 'POSITIVE', 'score': 0.9996284246444702}
# {'label': 'POSITIVE', 'score': 0.9988497495651245}
# {'label': 'POSITIVE', 'score': 0.994961142539978}
# {'label': 'NEGATIVE', 'score': 0.7421287894248962}
# {'label': 'NEGATIVE', 'score': 0.8138565421104431}
# {'label': 'POSITIVE', 'score': 0.9955884218215942}
# {'label': 'NEGATIVE', 'score': 0.9995735287666321}
# {'label': 'NEGATIVE', 'score': 0.9916118383407593}
# {'label': 'POSITIVE', 'score': 0.9986035227775574}
# {'label': 'POSITIVE', 'score': 0.9997355341911316}
# {'label': 'NEGATIVE', 'score': 0.8269981741905212}
# {'label': 'POSITIVE', 'score': 0.9977287650108337}
# {'label': 'NEGATIVE', 'score': 0.983182430267334}
# {'label': 'POSITIVE', 'score': 0.9899284243583679}
# {'label': 'NEGATIVE', 'score': 0.5769354701042175}
# {'label': 'NEGATIVE', 'score': 0.5693482756614685}
# {'label': 'NEGATIVE', 'score': 0.9929795861244202}
# {'label': 'POSITIVE', 'score': 0.9781913161277771}
# {'label': 'POSITIVE', 'score': 0.9928148984909058}
# {'label': 'NEGATIVE', 'score': 0.9997177720069885}
# {'label': 'NEGATIVE', 'score': 0.9961393475532532}
# {'label': 'POSITIVE', 'score': 0.9998807907104492}
# {'label': 'POSITIVE', 'score': 0.6301844120025635}
# {'label': 'POSITIVE', 'score': 0.9949725866317749}
# {'label': 'POSITIVE', 'score': 0.9994828701019287}
# {'label': 'POSITIVE', 'score': 0.9982287287712097}
# {'label': 'NEGATIVE', 'score': 0.9950432777404785}
# {'label': 'NEGATIVE', 'score': 0.9991656541824341}
# {'label': 'NEGATIVE', 'score': 0.9993755221366882}
# {'label': 'POSITIVE', 'score': 0.9992313385009766}
# {'label': 'POSITIVE', 'score': 0.9994301199913025}
# {'label': 'POSITIVE', 'score': 0.5941683053970337}
# {'label': 'POSITIVE', 'score': 0.9992334842681885}
# {'label': 'POSITIVE', 'score': 0.9993558526039124}
# {'label': 'POSITIVE', 'score': 0.9942335486412048}
# {'label': 'POSITIVE', 'score': 0.9983002543449402}
# {'label': 'POSITIVE', 'score': 0.9865887761116028}
# {'label': 'POSITIVE', 'score': 0.9972240924835205}
# {'label': 'POSITIVE', 'score': 0.999640703201294}
# {'label': 'POSITIVE', 'score': 0.7869120240211487}
# {'label': 'POSITIVE', 'score': 0.9068892002105713}
# {'label': 'POSITIVE', 'score': 0.9321128129959106}
# {'label': 'POSITIVE', 'score': 0.9961003065109253}
# {'label': 'POSITIVE', 'score': 0.9904658794403076}
# {'label': 'POSITIVE', 'score': 0.9844788908958435}
# {'label': 'POSITIVE', 'score': 0.998547375202179}
# {'label': 'NEGATIVE', 'score': 0.9824039936065674}
# {'label': 'POSITIVE', 'score': 0.6353210210800171}
# {'label': 'POSITIVE', 'score': 0.9997536540031433}
# {'label': 'POSITIVE', 'score': 0.9995331764221191}
# {'label': 'NEGATIVE', 'score': 0.9730982184410095}
# {'label': 'POSITIVE', 'score': 0.9995321035385132}
# {'label': 'POSITIVE', 'score': 0.7421596050262451}
# {'label': 'POSITIVE', 'score': 0.999496579170227}
# {'label': 'NEGATIVE', 'score': 0.9987069368362427}
# {'label': 'POSITIVE', 'score': 0.9996294975280762}
# {'label': 'POSITIVE', 'score': 0.9992601275444031}
# {'label': 'NEGATIVE', 'score': 0.5501737594604492}
# {'label': 'NEGATIVE', 'score': 0.9985811710357666}
# {'label': 'NEGATIVE', 'score': 0.9986329674720764}
# {'label': 'POSITIVE', 'score': 0.9995145797729492}
# {'label': 'POSITIVE', 'score': 0.9987479448318481}
# {'label': 'POSITIVE', 'score': 0.9708513617515564}
# {'label': 'NEGATIVE', 'score': 0.993537962436676}
# {'label': 'POSITIVE', 'score': 0.6795957684516907}
# {'label': 'POSITIVE', 'score': 0.5691383481025696}
# {'label': 'NEGATIVE', 'score': 0.994539201259613}
# {'label': 'POSITIVE', 'score': 0.9986253976821899}
# {'label': 'POSITIVE', 'score': 0.9998546838760376}
# {'label': 'POSITIVE', 'score': 0.9976378679275513}
# {'label': 'POSITIVE', 'score': 0.9876151084899902}
# {'label': 'POSITIVE', 'score': 0.9991394281387329}
# {'label': 'POSITIVE', 'score': 0.9996581077575684}
# {'label': 'NEGATIVE', 'score': 0.9955976605415344}
# {'label': 'POSITIVE', 'score': 0.9915030002593994}
# {'label': 'POSITIVE', 'score': 0.9996022582054138}
# {'label': 'POSITIVE', 'score': 0.9990474581718445}
# {'label': 'NEGATIVE', 'score': 0.999319314956665}
# {'label': 'NEGATIVE', 'score': 0.6862360239028931}
# {'label': 'NEGATIVE', 'score': 0.99931800365448}
# {'label': 'NEGATIVE', 'score': 0.9997995495796204}
# {'label': 'NEGATIVE', 'score': 0.9997285008430481}
# {'label': 'NEGATIVE', 'score': 0.9634958505630493}
# {'label': 'NEGATIVE', 'score': 0.999776303768158}
# {'label': 'NEGATIVE', 'score': 0.98728346824646}
# {'label': 'POSITIVE', 'score': 0.998863935470581}
# {'label': 'POSITIVE', 'score': 0.999338686466217}
# {'label': 'POSITIVE', 'score': 0.9977732300758362}
# {'label': 'POSITIVE', 'score': 0.9988579750061035}
# {'label': 'POSITIVE', 'score': 0.999800980091095}
# {'label': 'NEGATIVE', 'score': 0.9987496137619019}
# {'label': 'NEGATIVE', 'score': 0.9996615648269653}
# {'label': 'NEGATIVE', 'score': 0.9697015881538391}
# {'label': 'NEGATIVE', 'score': 0.9220983386039734}
# {'label': 'NEGATIVE', 'score': 0.9978517293930054}
# {'label': 'NEGATIVE', 'score': 0.9992371797561646}
# {'label': 'POSITIVE', 'score': 0.998891294002533}
# {'label': 'POSITIVE', 'score': 0.9858605861663818}
# {'label': 'POSITIVE', 'score': 0.8213682174682617}
# {'label': 'POSITIVE', 'score': 0.9966461062431335}
# {'label': 'POSITIVE', 'score': 0.9989504218101501}
# {'label': 'POSITIVE', 'score': 0.9710943102836609}
# {'label': 'POSITIVE', 'score': 0.9831551313400269}
# {'label': 'POSITIVE', 'score': 0.9924353957176208}
# {'label': 'POSITIVE', 'score': 0.999806821346283}
# {'label': 'POSITIVE', 'score': 0.9907640218734741}
# {'label': 'POSITIVE', 'score': 0.9991310238838196}
# {'label': 'POSITIVE', 'score': 0.9995195865631104}
# {'label': 'POSITIVE', 'score': 0.9996615648269653}
# {'label': 'POSITIVE', 'score': 0.9989556074142456}
# {'label': 'POSITIVE', 'score': 0.9991952776908875}
# {'label': 'POSITIVE', 'score': 0.9724926948547363}
# {'label': 'POSITIVE', 'score': 0.9998307228088379}
# {'label': 'POSITIVE', 'score': 0.9991961121559143}
# {'label': 'POSITIVE', 'score': 0.9997462630271912}
# {'label': 'POSITIVE', 'score': 0.9987354874610901}
# {'label': 'POSITIVE', 'score': 0.9997122883796692}
# {'label': 'POSITIVE', 'score': 0.9984415173530579}
# {'label': 'POSITIVE', 'score': 0.9997949004173279}
# {'label': 'POSITIVE', 'score': 0.9988777041435242}
# {'label': 'POSITIVE', 'score': 0.9995418787002563}
# {'label': 'POSITIVE', 'score': 0.5167281031608582}
# {'label': 'POSITIVE', 'score': 0.9992542862892151}
# {'label': 'NEGATIVE', 'score': 0.9991748929023743}
# {'label': 'POSITIVE', 'score': 0.9988129138946533}
# {'label': 'POSITIVE', 'score': 0.9990289211273193}
# {'label': 'POSITIVE', 'score': 0.9969189167022705}
# {'label': 'POSITIVE', 'score': 0.9310430884361267}
# {'label': 'NEGATIVE', 'score': 0.8671665787696838}
# {'label': 'POSITIVE', 'score': 0.9997840523719788}
# {'label': 'POSITIVE', 'score': 0.999193012714386}
# {'label': 'POSITIVE', 'score': 0.9996545314788818}
# {'label': 'POSITIVE', 'score': 0.9955784678459167}
# {'label': 'POSITIVE', 'score': 0.9995785355567932}
# {'label': 'POSITIVE', 'score': 0.9998592138290405}
# {'label': 'POSITIVE', 'score': 0.9988868832588196}
# {'label': 'NEGATIVE', 'score': 0.9962145686149597}
# {'label': 'POSITIVE', 'score': 0.9995844960212708}
# {'label': 'POSITIVE', 'score': 0.9995068311691284}
# {'label': 'NEGATIVE', 'score': 0.9997738003730774}
# {'label': 'NEGATIVE', 'score': 0.9995916485786438}
# {'label': 'NEGATIVE', 'score': 0.9981092214584351}
# {'label': 'NEGATIVE', 'score': 0.9997850060462952}
# {'label': 'NEGATIVE', 'score': 0.9995019435882568}
# {'label': 'NEGATIVE', 'score': 0.8713235259056091}
# {'label': 'NEGATIVE', 'score': 0.9902793765068054}
# {'label': 'NEGATIVE', 'score': 0.9953683614730835}
# {'label': 'NEGATIVE', 'score': 0.9997348189353943}
# {'label': 'POSITIVE', 'score': 0.936674952507019}
# {'label': 'POSITIVE', 'score': 0.9845112562179565}
# {'label': 'POSITIVE', 'score': 0.9998588562011719}
# {'label': 'POSITIVE', 'score': 0.9983805418014526}
# {'label': 'NEGATIVE', 'score': 0.9996678829193115}
# {'label': 'POSITIVE', 'score': 0.9998395442962646}
# {'label': 'POSITIVE', 'score': 0.999561607837677}
# {'label': 'NEGATIVE', 'score': 0.9994649291038513}
# {'label': 'POSITIVE', 'score': 0.9525012373924255}
# {'label': 'POSITIVE', 'score': 0.9998384714126587}
# {'label': 'NEGATIVE', 'score': 0.5270453095436096}
# {'label': 'NEGATIVE', 'score': 0.9964010715484619}
# {'label': 'POSITIVE', 'score': 0.9996869564056396}
# {'label': 'NEGATIVE', 'score': 0.9548532366752625}
# {'label': 'POSITIVE', 'score': 0.9995280504226685}
# {'label': 'POSITIVE', 'score': 0.9485557675361633}
# {'label': 'NEGATIVE', 'score': 0.6832705140113831}
# {'label': 'NEGATIVE', 'score': 0.9946757555007935}
# {'label': 'NEGATIVE', 'score': 0.9996654987335205}
# {'label': 'NEGATIVE', 'score': 0.998519241809845}
# {'label': 'NEGATIVE', 'score': 0.9994400143623352}
# {'label': 'NEGATIVE', 'score': 0.9943439960479736}
# {'label': 'NEGATIVE', 'score': 0.9997960925102234}
# {'label': 'NEGATIVE', 'score': 0.9614821672439575}
# {'label': 'POSITIVE', 'score': 0.9998437166213989}
# {'label': 'NEGATIVE', 'score': 0.999620795249939}
# {'label': 'POSITIVE', 'score': 0.9898663759231567}
# {'label': 'NEGATIVE', 'score': 0.9752660989761353}
# {'label': 'POSITIVE', 'score': 0.9995250701904297}
# {'label': 'POSITIVE', 'score': 0.999850869178772}
# {'label': 'POSITIVE', 'score': 0.9996949434280396}
# {'label': 'POSITIVE', 'score': 0.9783264398574829}
# {'label': 'POSITIVE', 'score': 0.9993183612823486}
# {'label': 'POSITIVE', 'score': 0.9998812675476074}
# {'label': 'POSITIVE', 'score': 0.9997015595436096}
# {'label': 'POSITIVE', 'score': 0.9998279809951782}
# {'label': 'POSITIVE', 'score': 0.9997802376747131}
# {'label': 'POSITIVE', 'score': 0.9974961876869202}
# {'label': 'POSITIVE', 'score': 0.9970412850379944}
# {'label': 'POSITIVE', 'score': 0.9951837658882141}
# {'label': 'POSITIVE', 'score': 0.9996365308761597}
# {'label': 'POSITIVE', 'score': 0.9988166093826294}
# {'label': 'POSITIVE', 'score': 0.9993261098861694}
# {'label': 'POSITIVE', 'score': 0.9972782731056213}
# {'label': 'POSITIVE', 'score': 0.9985363483428955}
# {'label': 'POSITIVE', 'score': 0.9987626075744629}
# {'label': 'NEGATIVE', 'score': 0.5900190472602844}
# {'label': 'NEGATIVE', 'score': 0.9987816214561462}
# {'label': 'NEGATIVE', 'score': 0.990172266960144}
# {'label': 'NEGATIVE', 'score': 0.999100923538208}
# {'label': 'POSITIVE', 'score': 0.993033766746521}
# {'label': 'NEGATIVE', 'score': 0.9966061115264893}
# {'label': 'POSITIVE', 'score': 0.9988698363304138}
# {'label': 'POSITIVE', 'score': 0.9881029725074768}
# {'label': 'POSITIVE', 'score': 0.9998518228530884}
# {'label': 'POSITIVE', 'score': 0.998384952545166}
# {'label': 'POSITIVE', 'score': 0.9857752323150635}
# {'label': 'POSITIVE', 'score': 0.9998681545257568}
# {'label': 'NEGATIVE', 'score': 0.9930096864700317}
# {'label': 'NEGATIVE', 'score': 0.9992883801460266}
# {'label': 'NEGATIVE', 'score': 0.9981050491333008}
# {'label': 'NEGATIVE', 'score': 0.999761164188385}
# {'label': 'NEGATIVE', 'score': 0.9958765506744385}
# {'label': 'NEGATIVE', 'score': 0.9997772574424744}
# {'label': 'NEGATIVE', 'score': 0.986011266708374}
# {'label': 'NEGATIVE', 'score': 0.9956637024879456}
# {'label': 'NEGATIVE', 'score': 0.9995611310005188}
# {'label': 'NEGATIVE', 'score': 0.9994927644729614}
# {'label': 'POSITIVE', 'score': 0.9760717153549194}
# {'label': 'NEGATIVE', 'score': 0.9997847676277161}
# {'label': 'NEGATIVE', 'score': 0.9997038245201111}
# {'label': 'POSITIVE', 'score': 0.9943716526031494}
# {'label': 'POSITIVE', 'score': 0.9992604851722717}
# {'label': 'POSITIVE', 'score': 0.9907329082489014}
# {'label': 'NEGATIVE', 'score': 0.9853644967079163}
# {'label': 'NEGATIVE', 'score': 0.9995967745780945}
# {'label': 'NEGATIVE', 'score': 0.9995933175086975}
# {'label': 'POSITIVE', 'score': 0.9995423555374146}
# {'label': 'POSITIVE', 'score': 0.9645785689353943}
# {'label': 'POSITIVE', 'score': 0.9901381731033325}
# {'label': 'POSITIVE', 'score': 0.9997506737709045}
# {'label': 'POSITIVE', 'score': 0.9998586177825928}
# {'label': 'POSITIVE', 'score': 0.9982019662857056}
# {'label': 'POSITIVE', 'score': 0.9978063702583313}
# {'label': 'POSITIVE', 'score': 0.9998530149459839}
# {'label': 'POSITIVE', 'score': 0.9996492862701416}
# {'label': 'POSITIVE', 'score': 0.9998574256896973}
# {'label': 'POSITIVE', 'score': 0.9988918900489807}
# {'label': 'NEGATIVE', 'score': 0.9998055100440979}
# {'label': 'POSITIVE', 'score': 0.9517756700515747}
# {'label': 'POSITIVE', 'score': 0.997543215751648}
# {'label': 'POSITIVE', 'score': 0.9980528354644775}
# {'label': 'POSITIVE', 'score': 0.9995819926261902}
# {'label': 'POSITIVE', 'score': 0.9997401833534241}
# {'label': 'POSITIVE', 'score': 0.999718964099884}
# {'label': 'POSITIVE', 'score': 0.9981098175048828}
# {'label': 'POSITIVE', 'score': 0.9998612403869629}
# {'label': 'POSITIVE', 'score': 0.9979405999183655}
# {'label': 'NEGATIVE', 'score': 0.9959343671798706}
# {'label': 'POSITIVE', 'score': 0.9978869557380676}
# {'label': 'POSITIVE', 'score': 0.9984305500984192}
# {'label': 'NEGATIVE', 'score': 0.7303034067153931}
# {'label': 'POSITIVE', 'score': 0.9807153940200806}
# {'label': 'POSITIVE', 'score': 0.9589232802391052}
# {'label': 'POSITIVE', 'score': 0.999136745929718}
# {'label': 'POSITIVE', 'score': 0.9994357228279114}
# {'label': 'POSITIVE', 'score': 0.9995562434196472}
# {'label': 'NEGATIVE', 'score': 0.9914333820343018}
# {'label': 'POSITIVE', 'score': 0.9987618923187256}
# {'label': 'POSITIVE', 'score': 0.9998595714569092}
# {'label': 'POSITIVE', 'score': 0.9994200468063354}
# {'label': 'POSITIVE', 'score': 0.999313473701477}
# {'label': 'POSITIVE', 'score': 0.9993276596069336}
# {'label': 'POSITIVE', 'score': 0.9972048401832581}
# {'label': 'POSITIVE', 'score': 0.9997047781944275}
# {'label': 'NEGATIVE', 'score': 0.5172791481018066}
# {'label': 'POSITIVE', 'score': 0.6037927269935608}
# {'label': 'POSITIVE', 'score': 0.999853253364563}
# {'label': 'NEGATIVE', 'score': 0.5466108918190002}
# {'label': 'POSITIVE', 'score': 0.9986714124679565}
# {'label': 'POSITIVE', 'score': 0.9854074120521545}
# {'label': 'POSITIVE', 'score': 0.9968204498291016}
# {'label': 'POSITIVE', 'score': 0.986344575881958}
# {'label': 'POSITIVE', 'score': 0.9998534917831421}
# {'label': 'POSITIVE', 'score': 0.9468369483947754}
# {'label': 'POSITIVE', 'score': 0.9985020160675049}
# {'label': 'NEGATIVE', 'score': 0.9946847558021545}
# {'label': 'POSITIVE', 'score': 0.6058319211006165}
# {'label': 'POSITIVE', 'score': 0.9962665438652039}
# {'label': 'POSITIVE', 'score': 0.9995717406272888}
# {'label': 'POSITIVE', 'score': 0.6851392388343811}
# {'label': 'POSITIVE', 'score': 0.9989080429077148}
# {'label': 'NEGATIVE', 'score': 0.9827418923377991}
# {'label': 'NEGATIVE', 'score': 0.9991468191146851}
# {'label': 'POSITIVE', 'score': 0.998306155204773}
# {'label': 'POSITIVE', 'score': 0.9975008368492126}
# {'label': 'POSITIVE', 'score': 0.7723292112350464}
# {'label': 'POSITIVE', 'score': 0.9990118741989136}
# {'label': 'POSITIVE', 'score': 0.998454213142395}
# {'label': 'NEGATIVE', 'score': 0.999489426612854}
# {'label': 'POSITIVE', 'score': 0.9996092915534973}
# {'label': 'POSITIVE', 'score': 0.9988768696784973}
# {'label': 'POSITIVE', 'score': 0.9978394508361816}
# {'label': 'POSITIVE', 'score': 0.9945525527000427}
# {'label': 'POSITIVE', 'score': 0.9936413168907166}
# {'label': 'POSITIVE', 'score': 0.9988811612129211}
# {'label': 'POSITIVE', 'score': 0.9991652965545654}
# {'label': 'NEGATIVE', 'score': 0.9673761129379272}
# {'label': 'NEGATIVE', 'score': 0.9930862188339233}
# {'label': 'POSITIVE', 'score': 0.9951536655426025}
# {'label': 'POSITIVE', 'score': 0.9984377026557922}
# {'label': 'POSITIVE', 'score': 0.9686042666435242}
# {'label': 'POSITIVE', 'score': 0.9878687262535095}
# {'label': 'POSITIVE', 'score': 0.9754242897033691}
# {'label': 'POSITIVE', 'score': 0.9996305704116821}
# {'label': 'POSITIVE', 'score': 0.9997361302375793}
# {'label': 'POSITIVE', 'score': 0.999347984790802}
# {'label': 'POSITIVE', 'score': 0.9997307658195496}
# {'label': 'POSITIVE', 'score': 0.990931510925293}
# {'label': 'POSITIVE', 'score': 0.9993158578872681}
# {'label': 'POSITIVE', 'score': 0.9956889748573303}
# {'label': 'POSITIVE', 'score': 0.9945540428161621}
# {'label': 'POSITIVE', 'score': 0.9970226883888245}
# {'label': 'POSITIVE', 'score': 0.9951110482215881}
# {'label': 'NEGATIVE', 'score': 0.9998050332069397}
# {'label': 'NEGATIVE', 'score': 0.9997417330741882}
# {'label': 'NEGATIVE', 'score': 0.9990814924240112}
# {'label': 'NEGATIVE', 'score': 0.9977699518203735}
# {'label': 'NEGATIVE', 'score': 0.9993109703063965}
# {'label': 'NEGATIVE', 'score': 0.984526515007019}
# {'label': 'NEGATIVE', 'score': 0.6929982304573059}
# {'label': 'POSITIVE', 'score': 0.752345085144043}
# {'label': 'NEGATIVE', 'score': 0.9820459485054016}
# {'label': 'POSITIVE', 'score': 0.9996211528778076}
# {'label': 'POSITIVE', 'score': 0.9989219903945923}
# {'label': 'POSITIVE', 'score': 0.5221427083015442}
# {'label': 'POSITIVE', 'score': 0.9934728741645813}
# {'label': 'POSITIVE', 'score': 0.9926905035972595}
# {'label': 'NEGATIVE', 'score': 0.7482053637504578}
# {'label': 'NEGATIVE', 'score': 0.9419906735420227}
# {'label': 'POSITIVE', 'score': 0.9996306896209717}
# {'label': 'POSITIVE', 'score': 0.999660849571228}
# {'label': 'POSITIVE', 'score': 0.625173807144165}
# {'label': 'NEGATIVE', 'score': 0.999484658241272}
# {'label': 'POSITIVE', 'score': 0.9872221350669861}
# {'label': 'NEGATIVE', 'score': 0.998138427734375}
# {'label': 'POSITIVE', 'score': 0.9984121322631836}
# {'label': 'POSITIVE', 'score': 0.9974834322929382}
# {'label': 'NEGATIVE', 'score': 0.9986860156059265}
# {'label': 'NEGATIVE', 'score': 0.9992934465408325}
# {'label': 'NEGATIVE', 'score': 0.9996931552886963}
# {'label': 'NEGATIVE', 'score': 0.9914148449897766}
# {'label': 'POSITIVE', 'score': 0.9978387951850891}
# {'label': 'POSITIVE', 'score': 0.9997417330741882}
# {'label': 'NEGATIVE', 'score': 0.9996930360794067}
# {'label': 'NEGATIVE', 'score': 0.9997178912162781}
# {'label': 'NEGATIVE', 'score': 0.9987095594406128}
# {'label': 'POSITIVE', 'score': 0.9816673994064331}
# {'label': 'NEGATIVE', 'score': 0.9989466071128845}
# {'label': 'POSITIVE', 'score': 0.9956454038619995}
# {'label': 'NEGATIVE', 'score': 0.5795323848724365}
# {'label': 'POSITIVE', 'score': 0.9978089928627014}
# {'label': 'POSITIVE', 'score': 0.9931471943855286}
# {'label': 'POSITIVE', 'score': 0.9972478747367859}
# {'label': 'NEGATIVE', 'score': 0.9987159967422485}
# {'label': 'NEGATIVE', 'score': 0.9987159967422485}
# {'label': 'NEGATIVE', 'score': 0.9531722664833069}
# {'label': 'POSITIVE', 'score': 0.9130685329437256}
# {'label': 'POSITIVE', 'score': 0.9998469352722168}
# {'label': 'POSITIVE', 'score': 0.9998506307601929}
# {'label': 'NEGATIVE', 'score': 0.9133221507072449}
# {'label': 'NEGATIVE', 'score': 0.9997655749320984}
# {'label': 'NEGATIVE', 'score': 0.9950048327445984}
# {'label': 'POSITIVE', 'score': 0.8450414538383484}
# {'label': 'POSITIVE', 'score': 0.9991249442100525}
# {'label': 'NEGATIVE', 'score': 0.9451276659965515}
# {'label': 'POSITIVE', 'score': 0.997005045413971}
# {'label': 'POSITIVE', 'score': 0.9946463704109192}
# {'label': 'POSITIVE', 'score': 0.9991499185562134}
# {'label': 'POSITIVE', 'score': 0.9997709393501282}
# {'label': 'POSITIVE', 'score': 0.9995017051696777}
# {'label': 'POSITIVE', 'score': 0.9653244614601135}
# {'label': 'POSITIVE', 'score': 0.9940547347068787}
# {'label': 'POSITIVE', 'score': 0.9982059001922607}
# {'label': 'POSITIVE', 'score': 0.9977319240570068}
# {'label': 'POSITIVE', 'score': 0.9944234490394592}
# {'label': 'POSITIVE', 'score': 0.9275432229042053}
# {'label': 'POSITIVE', 'score': 0.9903382658958435}
# {'label': 'POSITIVE', 'score': 0.9996906518936157}
# {'label': 'POSITIVE', 'score': 0.9734049439430237}
# {'label': 'POSITIVE', 'score': 0.9727585911750793}
# {'label': 'POSITIVE', 'score': 0.9955860376358032}
# {'label': 'POSITIVE', 'score': 0.9992578625679016}
# {'label': 'POSITIVE', 'score': 0.9993853569030762}
# {'label': 'NEGATIVE', 'score': 0.9922003149986267}
# {'label': 'NEGATIVE', 'score': 0.9417521953582764}
# {'label': 'POSITIVE', 'score': 0.999683141708374}
# {'label': 'POSITIVE', 'score': 0.9996432065963745}
# {'label': 'POSITIVE', 'score': 0.999617338180542}
# {'label': 'POSITIVE', 'score': 0.9960477948188782}
# {'label': 'POSITIVE', 'score': 0.9357550740242004}
# {'label': 'POSITIVE', 'score': 0.9837254881858826}
# {'label': 'NEGATIVE', 'score': 0.9758519530296326}
# {'label': 'NEGATIVE', 'score': 0.94010990858078}
# {'label': 'POSITIVE', 'score': 0.9970809817314148}
# {'label': 'NEGATIVE', 'score': 0.9607415199279785}
# {'label': 'POSITIVE', 'score': 0.999705970287323}
# {'label': 'POSITIVE', 'score': 0.5286231637001038}
# {'label': 'NEGATIVE', 'score': 0.9957090616226196}
# {'label': 'POSITIVE', 'score': 0.995404839515686}
# {'label': 'NEGATIVE', 'score': 0.9982516169548035}
# {'label': 'POSITIVE', 'score': 0.9993625283241272}
# {'label': 'POSITIVE', 'score': 0.998236894607544}
# {'label': 'NEGATIVE', 'score': 0.9969847798347473}
# {'label': 'NEGATIVE', 'score': 0.9993330836296082}
# {'label': 'NEGATIVE', 'score': 0.9701811075210571}
# {'label': 'POSITIVE', 'score': 0.920125424861908}
# {'label': 'POSITIVE', 'score': 0.9998156428337097}
# {'label': 'POSITIVE', 'score': 0.7292166948318481}
# {'label': 'NEGATIVE', 'score': 0.9840036034584045}
# {'label': 'NEGATIVE', 'score': 0.949540376663208}
# {'label': 'POSITIVE', 'score': 0.9968838095664978}
# {'label': 'POSITIVE', 'score': 0.9544544816017151}
# {'label': 'NEGATIVE', 'score': 0.7962472438812256}
# {'label': 'POSITIVE', 'score': 0.9996922016143799}
# {'label': 'POSITIVE', 'score': 0.9953925609588623}
# {'label': 'POSITIVE', 'score': 0.9993576407432556}
# {'label': 'POSITIVE', 'score': 0.9856406450271606}
# {'label': 'NEGATIVE', 'score': 0.9980024695396423}
# {'label': 'NEGATIVE', 'score': 0.9996836185455322}
# {'label': 'POSITIVE', 'score': 0.9809654355049133}
# {'label': 'NEGATIVE', 'score': 0.9967798590660095}
# {'label': 'NEGATIVE', 'score': 0.9964321851730347}
# {'label': 'NEGATIVE', 'score': 0.9996243715286255}
# {'label': 'NEGATIVE', 'score': 0.9997790455818176}
# {'label': 'NEGATIVE', 'score': 0.8510242104530334}
# {'label': 'NEGATIVE', 'score': 0.8727951645851135}
# {'label': 'POSITIVE', 'score': 0.9998530149459839}
# {'label': 'POSITIVE', 'score': 0.9994390606880188}
# {'label': 'POSITIVE', 'score': 0.9998387098312378}
# {'label': 'POSITIVE', 'score': 0.9993593096733093}
# {'label': 'POSITIVE', 'score': 0.9996045231819153}
# {'label': 'POSITIVE', 'score': 0.9998258948326111}
# {'label': 'POSITIVE', 'score': 0.9941412806510925}
# {'label': 'POSITIVE', 'score': 0.9977611303329468}
# {'label': 'POSITIVE', 'score': 0.9994586110115051}
# {'label': 'POSITIVE', 'score': 0.9988885521888733}
# {'label': 'POSITIVE', 'score': 0.9998856782913208}
# {'label': 'POSITIVE', 'score': 0.9998425245285034}
# {'label': 'POSITIVE', 'score': 0.9996989965438843}
# {'label': 'POSITIVE', 'score': 0.9989638328552246}
# {'label': 'POSITIVE', 'score': 0.9997519850730896}
# {'label': 'POSITIVE', 'score': 0.999519944190979}
# {'label': 'POSITIVE', 'score': 0.9815890789031982}
# {'label': 'POSITIVE', 'score': 0.9997370839118958}
# {'label': 'POSITIVE', 'score': 0.9997774958610535}
# {'label': 'POSITIVE', 'score': 0.9998546838760376}
# {'label': 'POSITIVE', 'score': 0.999299168586731}
# {'label': 'POSITIVE', 'score': 0.9993472695350647}
# {'label': 'POSITIVE', 'score': 0.998006284236908}
# {'label': 'NEGATIVE', 'score': 0.9985573887825012}
# {'label': 'POSITIVE', 'score': 0.999761164188385}
# {'label': 'NEGATIVE', 'score': 0.9851058721542358}
# {'label': 'POSITIVE', 'score': 0.999757707118988}
# {'label': 'POSITIVE', 'score': 0.9997326731681824}
# {'label': 'POSITIVE', 'score': 0.9954095482826233}
# {'label': 'POSITIVE', 'score': 0.9998027682304382}
# {'label': 'POSITIVE', 'score': 0.9984409213066101}
# {'label': 'NEGATIVE', 'score': 0.8224536776542664}
# {'label': 'POSITIVE', 'score': 0.9931598901748657}
# {'label': 'POSITIVE', 'score': 0.9987934827804565}
# {'label': 'POSITIVE', 'score': 0.9993491768836975}
# {'label': 'POSITIVE', 'score': 0.9998307228088379}
# {'label': 'POSITIVE', 'score': 0.9997701048851013}
# {'label': 'POSITIVE', 'score': 0.9945496916770935}
# {'label': 'POSITIVE', 'score': 0.9990501999855042}
# {'label': 'POSITIVE', 'score': 0.9985051155090332}
# {'label': 'POSITIVE', 'score': 0.9996415376663208}
# {'label': 'POSITIVE', 'score': 0.9903988838195801}
# {'label': 'POSITIVE', 'score': 0.9998255372047424}
# {'label': 'POSITIVE', 'score': 0.9939882755279541}
# {'label': 'NEGATIVE', 'score': 0.9986608028411865}
# {'label': 'POSITIVE', 'score': 0.9997314810752869}
# {'label': 'POSITIVE', 'score': 0.9995762705802917}
# {'label': 'POSITIVE', 'score': 0.9382442235946655}
# {'label': 'POSITIVE', 'score': 0.9404271245002747}
# {'label': 'POSITIVE', 'score': 0.9991055130958557}
# {'label': 'POSITIVE', 'score': 0.9976183772087097}
# {'label': 'POSITIVE', 'score': 0.7413458228111267}
# {'label': 'POSITIVE', 'score': 0.9987812638282776}
# {'label': 'POSITIVE', 'score': 0.9986385703086853}
# {'label': 'POSITIVE', 'score': 0.9550768136978149}
# {'label': 'POSITIVE', 'score': 0.996758759021759}
# {'label': 'NEGATIVE', 'score': 0.7524938583374023}
# {'label': 'NEGATIVE', 'score': 0.9961646795272827}
# {'label': 'NEGATIVE', 'score': 0.9990620017051697}
# {'label': 'POSITIVE', 'score': 0.9993587136268616}
# {'label': 'NEGATIVE', 'score': 0.9922075867652893}
# {'label': 'NEGATIVE', 'score': 0.9996695518493652}
# {'label': 'POSITIVE', 'score': 0.9993495345115662}
# {'label': 'NEGATIVE', 'score': 0.8387925028800964}
# {'label': 'NEGATIVE', 'score': 0.9935033917427063}
# {'label': 'POSITIVE', 'score': 0.9979267120361328}
# {'label': 'NEGATIVE', 'score': 0.9984000325202942}
# {'label': 'POSITIVE', 'score': 0.9996064305305481}
# {'label': 'POSITIVE', 'score': 0.9991074204444885}
# {'label': 'POSITIVE', 'score': 0.9990947246551514}
# {'label': 'POSITIVE', 'score': 0.9996800422668457}
# {'label': 'POSITIVE', 'score': 0.9997765421867371}
# {'label': 'POSITIVE', 'score': 0.9998823404312134}
# {'label': 'POSITIVE', 'score': 0.9996887445449829}
# {'label': 'POSITIVE', 'score': 0.9973875880241394}
# {'label': 'POSITIVE', 'score': 0.999561607837677}
# {'label': 'POSITIVE', 'score': 0.999764621257782}
# {'label': 'POSITIVE', 'score': 0.9966683983802795}
# {'label': 'POSITIVE', 'score': 0.9949913620948792}
# {'label': 'POSITIVE', 'score': 0.9998760223388672}
# {'label': 'POSITIVE', 'score': 0.999518871307373}
# {'label': 'POSITIVE', 'score': 0.9998431205749512}
# {'label': 'POSITIVE', 'score': 0.9996651411056519}
# {'label': 'POSITIVE', 'score': 0.999858021736145}
# {'label': 'POSITIVE', 'score': 0.9998518228530884}
# {'label': 'POSITIVE', 'score': 0.9998518228530884}
# {'label': 'POSITIVE', 'score': 0.9987982511520386}
# {'label': 'POSITIVE', 'score': 0.9998856782913208}
# {'label': 'NEGATIVE', 'score': 0.9946637153625488}
# {'label': 'POSITIVE', 'score': 0.9996424913406372}
# {'label': 'POSITIVE', 'score': 0.9989578723907471}
# {'label': 'POSITIVE', 'score': 0.9903014898300171}
# {'label': 'POSITIVE', 'score': 0.9995887875556946}
# {'label': 'POSITIVE', 'score': 0.9981990456581116}
# {'label': 'NEGATIVE', 'score': 0.9986969828605652}
# {'label': 'POSITIVE', 'score': 0.9997434020042419}
# {'label': 'NEGATIVE', 'score': 0.9777087569236755}
# {'label': 'POSITIVE', 'score': 0.9997434020042419}
# {'label': 'POSITIVE', 'score': 0.9747013449668884}
# {'label': 'POSITIVE', 'score': 0.9998623132705688}
# {'label': 'POSITIVE', 'score': 0.9998500347137451}
# {'label': 'POSITIVE', 'score': 0.9996799230575562}
# {'label': 'NEGATIVE', 'score': 0.8615844249725342}
# {'label': 'POSITIVE', 'score': 0.9032286405563354}
# {'label': 'POSITIVE', 'score': 0.9993045330047607}
# {'label': 'POSITIVE', 'score': 0.9917510151863098}
# {'label': 'NEGATIVE', 'score': 0.9985105395317078}
# {'label': 'NEGATIVE', 'score': 0.9985337257385254}
# {'label': 'POSITIVE', 'score': 0.9687775373458862}
# {'label': 'POSITIVE', 'score': 0.995246946811676}
# {'label': 'POSITIVE', 'score': 0.9995741248130798}
# {'label': 'POSITIVE', 'score': 0.9997498393058777}
# {'label': 'NEGATIVE', 'score': 0.9991204142570496}
# {'label': 'NEGATIVE', 'score': 0.9993566870689392}
# {'label': 'NEGATIVE', 'score': 0.999496579170227}
# {'label': 'POSITIVE', 'score': 0.9993013143539429}
# {'label': 'NEGATIVE', 'score': 0.99783855676651}
# {'label': 'NEGATIVE', 'score': 0.9915459752082825}
# {'label': 'NEGATIVE', 'score': 0.9994657635688782}
# {'label': 'POSITIVE', 'score': 0.9899469017982483}
# {'label': 'NEGATIVE', 'score': 0.9993098974227905}
# {'label': 'NEGATIVE', 'score': 0.9997579455375671}
# {'label': 'POSITIVE', 'score': 0.9827318787574768}
# {'label': 'NEGATIVE', 'score': 0.9997974038124084}
# {'label': 'NEGATIVE', 'score': 0.999496579170227}
# {'label': 'NEGATIVE', 'score': 0.9811303019523621}
# {'label': 'POSITIVE', 'score': 0.9980055689811707}
# {'label': 'POSITIVE', 'score': 0.9985976815223694}
# {'label': 'NEGATIVE', 'score': 0.9953965544700623}
# {'label': 'NEGATIVE', 'score': 0.9998103976249695}
# {'label': 'POSITIVE', 'score': 0.9937908053398132}
# {'label': 'NEGATIVE', 'score': 0.9996789693832397}
# {'label': 'NEGATIVE', 'score': 0.6517246961593628}
# {'label': 'POSITIVE', 'score': 0.9916352033615112}
# {'label': 'POSITIVE', 'score': 0.9997866749763489}
# {'label': 'POSITIVE', 'score': 0.9977648258209229}
# {'label': 'NEGATIVE', 'score': 0.9777766466140747}
# {'label': 'POSITIVE', 'score': 0.9980674386024475}
# {'label': 'POSITIVE', 'score': 0.9994655251502991}
# {'label': 'POSITIVE', 'score': 0.9970157146453857}
# {'label': 'NEGATIVE', 'score': 0.999572217464447}
# {'label': 'POSITIVE', 'score': 0.9890397787094116}
# {'label': 'NEGATIVE', 'score': 0.9995707869529724}
# {'label': 'POSITIVE', 'score': 0.9983453750610352}
# {'label': 'POSITIVE', 'score': 0.9962825179100037}
# {'label': 'POSITIVE', 'score': 0.9998685121536255}
# {'label': 'POSITIVE', 'score': 0.9997771382331848}
# {'label': 'POSITIVE', 'score': 0.9803537726402283}
# {'label': 'POSITIVE', 'score': 0.9937098026275635}
# {'label': 'POSITIVE', 'score': 0.9984690546989441}
# {'label': 'NEGATIVE', 'score': 0.9859209656715393}
# {'label': 'POSITIVE', 'score': 0.9958966970443726}
# {'label': 'POSITIVE', 'score': 0.9950459003448486}
# {'label': 'NEGATIVE', 'score': 0.9918950200080872}
# {'label': 'NEGATIVE', 'score': 0.9957846999168396}
# {'label': 'NEGATIVE', 'score': 0.9572942852973938}
# {'label': 'POSITIVE', 'score': 0.9987664222717285}
# {'label': 'NEGATIVE', 'score': 0.8719015121459961}
# {'label': 'NEGATIVE', 'score': 0.9923946857452393}
# {'label': 'NEGATIVE', 'score': 0.9891020655632019}
# {'label': 'POSITIVE', 'score': 0.9993021488189697}
# {'label': 'NEGATIVE', 'score': 0.9951874017715454}
# {'label': 'NEGATIVE', 'score': 0.9783747792243958}
# {'label': 'NEGATIVE', 'score': 0.9849104285240173}
# {'label': 'NEGATIVE', 'score': 0.9956409931182861}
# {'label': 'NEGATIVE', 'score': 0.9988574981689453}
# {'label': 'NEGATIVE', 'score': 0.9110950827598572}
# {'label': 'POSITIVE', 'score': 0.9923926591873169}
# {'label': 'NEGATIVE', 'score': 0.9572994112968445}
# {'label': 'NEGATIVE', 'score': 0.9970799088478088}
# {'label': 'NEGATIVE', 'score': 0.9997894167900085}
# {'label': 'NEGATIVE', 'score': 0.9994906187057495}
# {'label': 'POSITIVE', 'score': 0.999071478843689}
# {'label': 'NEGATIVE', 'score': 0.9976680874824524}
# {'label': 'POSITIVE', 'score': 0.9997522234916687}
# {'label': 'NEGATIVE', 'score': 0.7518916726112366}
# {'label': 'POSITIVE', 'score': 0.9992445707321167}
# {'label': 'POSITIVE', 'score': 0.9995217323303223}
# {'label': 'POSITIVE', 'score': 0.9994311928749084}
# {'label': 'POSITIVE', 'score': 0.9993603825569153}
# {'label': 'POSITIVE', 'score': 0.9990552067756653}
# {'label': 'POSITIVE', 'score': 0.9995265007019043}
# {'label': 'POSITIVE', 'score': 0.5828720927238464}
# {'label': 'POSITIVE', 'score': 0.5072365403175354}
# {'label': 'POSITIVE', 'score': 0.9843714833259583}
# {'label': 'POSITIVE', 'score': 0.9996854066848755}
# {'label': 'NEGATIVE', 'score': 0.9338626265525818}
# {'label': 'POSITIVE', 'score': 0.9991944432258606}
# {'label': 'POSITIVE', 'score': 0.9750800728797913}
# {'label': 'POSITIVE', 'score': 0.9986546039581299}
# {'label': 'NEGATIVE', 'score': 0.6416198015213013}
# {'label': 'POSITIVE', 'score': 0.9994776844978333}
# {'label': 'POSITIVE', 'score': 0.9961638450622559}
# {'label': 'POSITIVE', 'score': 0.8621832728385925}
# {'label': 'NEGATIVE', 'score': 0.986941397190094}
# {'label': 'NEGATIVE', 'score': 0.9991397857666016}
# {'label': 'NEGATIVE', 'score': 0.9994634985923767}
# {'label': 'NEGATIVE', 'score': 0.9997435212135315}
# {'label': 'POSITIVE', 'score': 0.9986374974250793}
# {'label': 'POSITIVE', 'score': 0.9987285733222961}
# {'label': 'POSITIVE', 'score': 0.9998304843902588}
# {'label': 'NEGATIVE', 'score': 0.9990540146827698}
# {'label': 'NEGATIVE', 'score': 0.9994972944259644}
# {'label': 'NEGATIVE', 'score': 0.9998093247413635}
# {'label': 'POSITIVE', 'score': 0.9995459914207458}
# {'label': 'NEGATIVE', 'score': 0.9988529682159424}
# {'label': 'NEGATIVE', 'score': 0.999546468257904}
# {'label': 'POSITIVE', 'score': 0.9982306361198425}
# {'label': 'POSITIVE', 'score': 0.998854398727417}
# {'label': 'POSITIVE', 'score': 0.9899043440818787}
# {'label': 'POSITIVE', 'score': 0.9991525411605835}
# {'label': 'POSITIVE', 'score': 0.9997400641441345}
# {'label': 'POSITIVE', 'score': 0.9978857636451721}
# {'label': 'NEGATIVE', 'score': 0.6261935830116272}
# {'label': 'POSITIVE', 'score': 0.9995775818824768}
# {'label': 'NEGATIVE', 'score': 0.9567260146141052}
# {'label': 'POSITIVE', 'score': 0.9988125562667847}
# {'label': 'NEGATIVE', 'score': 0.9968872666358948}
# {'label': 'POSITIVE', 'score': 0.8630154728889465}
# {'label': 'NEGATIVE', 'score': 0.9687504768371582}
# {'label': 'POSITIVE', 'score': 0.9881078600883484}
# {'label': 'NEGATIVE', 'score': 0.9997298121452332}
# {'label': 'POSITIVE', 'score': 0.9949136972427368}
# {'label': 'POSITIVE', 'score': 0.9809008240699768}
# {'label': 'NEGATIVE', 'score': 0.9934706687927246}
# {'label': 'POSITIVE', 'score': 0.9849076271057129}
# {'label': 'NEGATIVE', 'score': 0.8745464086532593}
# {'label': 'POSITIVE', 'score': 0.9972111582756042}
# {'label': 'POSITIVE', 'score': 0.9983245730400085}
# {'label': 'POSITIVE', 'score': 0.999779999256134}
# {'label': 'POSITIVE', 'score': 0.9995113611221313}
# {'label': 'POSITIVE', 'score': 0.9980757236480713}
# {'label': 'NEGATIVE', 'score': 0.9993526339530945}
# {'label': 'NEGATIVE', 'score': 0.9996815919876099}
# {'label': 'NEGATIVE', 'score': 0.9992640614509583}
# {'label': 'NEGATIVE', 'score': 0.9997957348823547}
# {'label': 'NEGATIVE', 'score': 0.998917818069458}
# {'label': 'NEGATIVE', 'score': 0.9996986389160156}
# {'label': 'NEGATIVE', 'score': 0.9940185546875}
# {'label': 'POSITIVE', 'score': 0.967470645904541}
# {'label': 'POSITIVE', 'score': 0.9968114495277405}
# {'label': 'NEGATIVE', 'score': 0.9810125827789307}
# {'label': 'POSITIVE', 'score': 0.9998685121536255}
# {'label': 'POSITIVE', 'score': 0.8399416208267212}
# ...
# {'label': 'NEGATIVE', 'score': 0.9995487332344055}
# {'label': 'NEGATIVE', 'score': 0.9929012060165405}
# {'label': 'NEGATIVE', 'score': 0.9763968586921692}
# {'label': 'NEGATIVE', 'score': 0.9971953630447388}
# {'label': 'POSITIVE', 'score': 0.9615516066551208}
# {'label': 'NEGATIVE', 'score': 0.9978548884391785}
# {'label': 'NEGATIVE', 'score': 0.9966237545013428}
# {'label': 'NEGATIVE', 'score': 0.9997377991676331}
# {'label': 'NEGATIVE', 'score': 0.9977515339851379}
# {'label': 'NEGATIVE', 'score': 0.9975233674049377}
# {'label': 'NEGATIVE', 'score': 0.7402772903442383}
# {'label': 'NEGATIVE', 'score': 0.998336672782898}
# {'label': 'NEGATIVE', 'score': 0.9919579029083252}
# {'label': 'NEGATIVE', 'score': 0.9993359446525574}
# {'label': 'NEGATIVE', 'score': 0.9985791444778442}
# {'label': 'NEGATIVE', 'score': 0.9997875094413757}
# {'label': 'NEGATIVE', 'score': 0.9998014569282532}
# {'label': 'NEGATIVE', 'score': 0.9967842102050781}
# {'label': 'NEGATIVE', 'score': 0.9906911253929138}
# {'label': 'NEGATIVE', 'score': 0.9995574355125427}
# {'label': 'NEGATIVE', 'score': 0.9992964267730713}
# {'label': 'NEGATIVE', 'score': 0.9997535347938538}
# {'label': 'NEGATIVE', 'score': 0.9946125745773315}
# {'label': 'NEGATIVE', 'score': 0.9997218251228333}
# {'label': 'NEGATIVE', 'score': 0.9939391613006592}
# {'label': 'NEGATIVE', 'score': 0.9748120903968811}
# {'label': 'NEGATIVE', 'score': 0.9977359771728516}
# {'label': 'NEGATIVE', 'score': 0.9890311360359192}
# {'label': 'NEGATIVE', 'score': 0.9987568855285645}
# {'label': 'NEGATIVE', 'score': 0.9997037053108215}
# {'label': 'NEGATIVE', 'score': 0.9880335330963135}
# {'label': 'NEGATIVE', 'score': 0.9973486661911011}
# {'label': 'NEGATIVE', 'score': 0.9990442395210266}
# {'label': 'NEGATIVE', 'score': 0.9994519352912903}
# {'label': 'NEGATIVE', 'score': 0.9985988736152649}
# {'label': 'NEGATIVE', 'score': 0.9987167119979858}
# {'label': 'NEGATIVE', 'score': 0.9989765882492065}
# {'label': 'NEGATIVE', 'score': 0.9225208759307861}
# {'label': 'NEGATIVE', 'score': 0.9913889765739441}
# {'label': 'NEGATIVE', 'score': 0.9993294477462769}
# {'label': 'NEGATIVE', 'score': 0.9981936812400818}
# {'label': 'NEGATIVE', 'score': 0.9971998929977417}
# {'label': 'NEGATIVE', 'score': 0.9908856749534607}
# {'label': 'NEGATIVE', 'score': 0.9756931662559509}
# {'label': 'NEGATIVE', 'score': 0.9969685673713684}
# {'label': 'NEGATIVE', 'score': 0.9995298385620117}
# {'label': 'NEGATIVE', 'score': 0.9863132238388062}
# {'label': 'NEGATIVE', 'score': 0.9988085031509399}
# {'label': 'NEGATIVE', 'score': 0.9997674822807312}
# {'label': 'NEGATIVE', 'score': 0.9986249208450317}
# {'label': 'NEGATIVE', 'score': 0.9989431500434875}
# {'label': 'NEGATIVE', 'score': 0.9982140064239502}
# {'label': 'NEGATIVE', 'score': 0.9990260601043701}
# {'label': 'NEGATIVE', 'score': 0.9994269609451294}
# {'label': 'POSITIVE', 'score': 0.9993081092834473}
# {'label': 'NEGATIVE', 'score': 0.9941648840904236}
# {'label': 'NEGATIVE', 'score': 0.9997510313987732}
# {'label': 'NEGATIVE', 'score': 0.9993731379508972}
# {'label': 'NEGATIVE', 'score': 0.9815338253974915}
# {'label': 'NEGATIVE', 'score': 0.9986171722412109}
# {'label': 'NEGATIVE', 'score': 0.951044499874115}
# {'label': 'NEGATIVE', 'score': 0.993556559085846}
# {'label': 'NEGATIVE', 'score': 0.936385989189148}
# {'label': 'NEGATIVE', 'score': 0.9808101058006287}
# {'label': 'NEGATIVE', 'score': 0.7328608632087708}
# {'label': 'NEGATIVE', 'score': 0.9997847676277161}
# {'label': 'NEGATIVE', 'score': 0.9996057152748108}
# {'label': 'NEGATIVE', 'score': 0.9952079653739929}
# {'label': 'POSITIVE', 'score': 0.5184968709945679}
# {'label': 'NEGATIVE', 'score': 0.9995502829551697}
# {'label': 'NEGATIVE', 'score': 0.9950686693191528}
# {'label': 'NEGATIVE', 'score': 0.9990119934082031}
# {'label': 'NEGATIVE', 'score': 0.9953327775001526}
# {'label': 'NEGATIVE', 'score': 0.997514009475708}
# {'label': 'POSITIVE', 'score': 0.9783318638801575}
# {'label': 'NEGATIVE', 'score': 0.9858943223953247}
# {'label': 'POSITIVE', 'score': 0.9939633011817932}
# {'label': 'NEGATIVE', 'score': 0.9993141889572144}
# {'label': 'NEGATIVE', 'score': 0.9992153644561768}
# {'label': 'NEGATIVE', 'score': 0.9989564418792725}
# {'label': 'NEGATIVE', 'score': 0.9996219873428345}
# {'label': 'NEGATIVE', 'score': 0.9553436636924744}
# {'label': 'POSITIVE', 'score': 0.9905697107315063}
# {'label': 'POSITIVE', 'score': 0.9750316739082336}
# {'label': 'NEGATIVE', 'score': 0.9985712766647339}
# {'label': 'NEGATIVE', 'score': 0.9997962117195129}
# {'label': 'POSITIVE', 'score': 0.7334234118461609}
# {'label': 'NEGATIVE', 'score': 0.9988138675689697}
# {'label': 'NEGATIVE', 'score': 0.9993808269500732}
# {'label': 'NEGATIVE', 'score': 0.9994656443595886}
# {'label': 'NEGATIVE', 'score': 0.999235987663269}
# {'label': 'NEGATIVE', 'score': 0.9904528856277466}
# {'label': 'NEGATIVE', 'score': 0.9991292357444763}
# {'label': 'NEGATIVE', 'score': 0.7970494031906128}
# {'label': 'NEGATIVE', 'score': 0.9997459053993225}
# {'label': 'NEGATIVE', 'score': 0.9996906518936157}
# {'label': 'NEGATIVE', 'score': 0.9961628913879395}
# {'label': 'POSITIVE', 'score': 0.8238664269447327}
# {'label': 'NEGATIVE', 'score': 0.9986164569854736}
# {'label': 'NEGATIVE', 'score': 0.995062530040741}
# {'label': 'NEGATIVE', 'score': 0.9951973557472229}
# {'label': 'NEGATIVE', 'score': 0.9940464496612549}
# {'label': 'NEGATIVE', 'score': 0.9992914199829102}
# {'label': 'NEGATIVE', 'score': 0.9972363710403442}
# {'label': 'NEGATIVE', 'score': 0.9945854544639587}
# {'label': 'POSITIVE', 'score': 0.992803156375885}
# {'label': 'NEGATIVE', 'score': 0.99850994348526}
# {'label': 'NEGATIVE', 'score': 0.999347984790802}
# {'label': 'NEGATIVE', 'score': 0.9940741658210754}
# {'label': 'NEGATIVE', 'score': 0.9970947504043579}
# {'label': 'NEGATIVE', 'score': 0.9995484948158264}
# {'label': 'NEGATIVE', 'score': 0.9990590214729309}
# {'label': 'NEGATIVE', 'score': 0.9946847558021545}
# {'label': 'NEGATIVE', 'score': 0.9991468191146851}
# {'label': 'NEGATIVE', 'score': 0.9991907477378845}
# {'label': 'NEGATIVE', 'score': 0.9986683130264282}
# {'label': 'NEGATIVE', 'score': 0.9989562034606934}
# {'label': 'NEGATIVE', 'score': 0.9995647072792053}
# {'label': 'NEGATIVE', 'score': 0.9934978485107422}
# {'label': 'NEGATIVE', 'score': 0.9937230944633484}
# {'label': 'NEGATIVE', 'score': 0.9981915354728699}
# {'label': 'NEGATIVE', 'score': 0.999594509601593}
# {'label': 'POSITIVE', 'score': 0.9830297827720642}
# {'label': 'NEGATIVE', 'score': 0.9991632699966431}
# {'label': 'NEGATIVE', 'score': 0.9993658661842346}
# {'label': 'NEGATIVE', 'score': 0.9995260238647461}
# {'label': 'NEGATIVE', 'score': 0.9997298121452332}
# {'label': 'NEGATIVE', 'score': 0.9993587136268616}
# {'label': 'NEGATIVE', 'score': 0.9997809529304504}
# {'label': 'NEGATIVE', 'score': 0.9986845850944519}
# {'label': 'NEGATIVE', 'score': 0.9042227268218994}
# {'label': 'NEGATIVE', 'score': 0.9997443556785583}
# {'label': 'NEGATIVE', 'score': 0.9988822340965271}
# {'label': 'NEGATIVE', 'score': 0.9996746778488159}
# {'label': 'NEGATIVE', 'score': 0.998536229133606}
# {'label': 'NEGATIVE', 'score': 0.9084321856498718}
# {'label': 'NEGATIVE', 'score': 0.7178886532783508}
# {'label': 'NEGATIVE', 'score': 0.9883663058280945}
# {'label': 'NEGATIVE', 'score': 0.9994295239448547}
# {'label': 'NEGATIVE', 'score': 0.9986804127693176}
# {'label': 'NEGATIVE', 'score': 0.9836776256561279}
# {'label': 'NEGATIVE', 'score': 0.9996756315231323}
# {'label': 'POSITIVE', 'score': 0.6370205879211426}
# {'label': 'NEGATIVE', 'score': 0.9993882179260254}
# {'label': 'NEGATIVE', 'score': 0.9992032647132874}
# {'label': 'NEGATIVE', 'score': 0.9962928891181946}
# {'label': 'NEGATIVE', 'score': 0.9996925592422485}
# {'label': 'NEGATIVE', 'score': 0.9997021555900574}
# {'label': 'NEGATIVE', 'score': 0.9957932233810425}
# {'label': 'NEGATIVE', 'score': 0.9992333650588989}
# {'label': 'NEGATIVE', 'score': 0.9985272884368896}
# {'label': 'NEGATIVE', 'score': 0.9988208413124084}
# {'label': 'NEGATIVE', 'score': 0.9447463750839233}
# {'label': 'NEGATIVE', 'score': 0.9997562766075134}
# {'label': 'NEGATIVE', 'score': 0.9940140843391418}
# {'label': 'NEGATIVE', 'score': 0.9998207688331604}
# {'label': 'NEGATIVE', 'score': 0.9987157583236694}
# {'label': 'NEGATIVE', 'score': 0.9966296553611755}
# {'label': 'NEGATIVE', 'score': 0.9995836615562439}
# {'label': 'NEGATIVE', 'score': 0.9838953614234924}
# {'label': 'NEGATIVE', 'score': 0.9988759160041809}
# {'label': 'NEGATIVE', 'score': 0.9998086094856262}
# {'label': 'NEGATIVE', 'score': 0.9991801381111145}
# {'label': 'POSITIVE', 'score': 0.9670338034629822}
# {'label': 'NEGATIVE', 'score': 0.9994739890098572}
# {'label': 'NEGATIVE', 'score': 0.9972917437553406}
# {'label': 'NEGATIVE', 'score': 0.9988197684288025}
# {'label': 'NEGATIVE', 'score': 0.9990321397781372}
# {'label': 'NEGATIVE', 'score': 0.9996114373207092}
# {'label': 'NEGATIVE', 'score': 0.9994773268699646}
# {'label': 'NEGATIVE', 'score': 0.9978952407836914}
# {'label': 'NEGATIVE', 'score': 0.9969571828842163}
# {'label': 'NEGATIVE', 'score': 0.9997811913490295}
# {'label': 'NEGATIVE', 'score': 0.998465895652771}
# {'label': 'NEGATIVE', 'score': 0.9984170198440552}
# {'label': 'NEGATIVE', 'score': 0.9998037219047546}
# {'label': 'NEGATIVE', 'score': 0.9979348182678223}
# {'label': 'NEGATIVE', 'score': 0.9986785054206848}
# {'label': 'NEGATIVE', 'score': 0.9877726435661316}
# {'label': 'NEGATIVE', 'score': 0.9992175102233887}
# {'label': 'NEGATIVE', 'score': 0.9997286200523376}
# {'label': 'NEGATIVE', 'score': 0.9997712969779968}
# {'label': 'NEGATIVE', 'score': 0.9965619444847107}
# {'label': 'NEGATIVE', 'score': 0.953061580657959}
# {'label': 'POSITIVE', 'score': 0.7418250441551208}
# {'label': 'NEGATIVE', 'score': 0.9981062412261963}
# {'label': 'NEGATIVE', 'score': 0.9943081736564636}
# {'label': 'NEGATIVE', 'score': 0.9997549653053284}
# {'label': 'NEGATIVE', 'score': 0.9968217611312866}
# {'label': 'NEGATIVE', 'score': 0.9985365867614746}
# {'label': 'NEGATIVE', 'score': 0.999103307723999}
# {'label': 'NEGATIVE', 'score': 0.9993053674697876}
# {'label': 'NEGATIVE', 'score': 0.9997302889823914}
# {'label': 'NEGATIVE', 'score': 0.9997932314872742}
# {'label': 'NEGATIVE', 'score': 0.9995966553688049}
# {'label': 'NEGATIVE', 'score': 0.9694806933403015}
# {'label': 'NEGATIVE', 'score': 0.9992895126342773}
# {'label': 'NEGATIVE', 'score': 0.9996575117111206}
# {'label': 'NEGATIVE', 'score': 0.9991381168365479}
# {'label': 'NEGATIVE', 'score': 0.9995332956314087}
# {'label': 'NEGATIVE', 'score': 0.9994364380836487}
# {'label': 'NEGATIVE', 'score': 0.9993755221366882}
# {'label': 'NEGATIVE', 'score': 0.9752171039581299}
# {'label': 'NEGATIVE', 'score': 0.9996590614318848}
# {'label': 'NEGATIVE', 'score': 0.986788272857666}
# {'label': 'NEGATIVE', 'score': 0.9983874559402466}
# {'label': 'NEGATIVE', 'score': 0.9997296929359436}
# {'label': 'NEGATIVE', 'score': 0.9993187189102173}
# {'label': 'NEGATIVE', 'score': 0.9991611242294312}
# {'label': 'NEGATIVE', 'score': 0.9997178912162781}
# {'label': 'POSITIVE', 'score': 0.982326090335846}
# {'label': 'NEGATIVE', 'score': 0.9902665019035339}
# {'label': 'NEGATIVE', 'score': 0.9353498220443726}
# {'label': 'NEGATIVE', 'score': 0.9995635151863098}
# {'label': 'NEGATIVE', 'score': 0.9991865754127502}
# {'label': 'NEGATIVE', 'score': 0.9979447722434998}
# {'label': 'NEGATIVE', 'score': 0.9975403547286987}
# {'label': 'NEGATIVE', 'score': 0.9997654557228088}
# {'label': 'NEGATIVE', 'score': 0.9963833093643188}
# {'label': 'NEGATIVE', 'score': 0.9996533393859863}
# {'label': 'POSITIVE', 'score': 0.9171018600463867}
# {'label': 'NEGATIVE', 'score': 0.9997453093528748}
# {'label': 'NEGATIVE', 'score': 0.9954044818878174}
# {'label': 'NEGATIVE', 'score': 0.9832379817962646}
# {'label': 'NEGATIVE', 'score': 0.9993696808815002}
# {'label': 'NEGATIVE', 'score': 0.9994686245918274}
# {'label': 'NEGATIVE', 'score': 0.9983559250831604}
# {'label': 'NEGATIVE', 'score': 0.9977505803108215}
# {'label': 'NEGATIVE', 'score': 0.9932368397712708}
# {'label': 'NEGATIVE', 'score': 0.9966955184936523}
# {'label': 'NEGATIVE', 'score': 0.9767929315567017}
# {'label': 'POSITIVE', 'score': 0.9821948409080505}
# {'label': 'NEGATIVE', 'score': 0.9983420372009277}
# {'label': 'NEGATIVE', 'score': 0.9976038336753845}
# {'label': 'NEGATIVE', 'score': 0.9996434450149536}
# {'label': 'NEGATIVE', 'score': 0.8294680714607239}
# {'label': 'NEGATIVE', 'score': 0.9996799230575562}
# {'label': 'NEGATIVE', 'score': 0.998847246170044}
# {'label': 'NEGATIVE', 'score': 0.9887446165084839}
# {'label': 'NEGATIVE', 'score': 0.9969491362571716}
# {'label': 'NEGATIVE', 'score': 0.9978334307670593}
# {'label': 'POSITIVE', 'score': 0.5031383633613586}
# {'label': 'NEGATIVE', 'score': 0.9996852874755859}
# {'label': 'NEGATIVE', 'score': 0.9993239641189575}
# {'label': 'NEGATIVE', 'score': 0.9984686970710754}
# {'label': 'NEGATIVE', 'score': 0.9997711777687073}
# {'label': 'NEGATIVE', 'score': 0.9986416697502136}
# {'label': 'POSITIVE', 'score': 0.5774511098861694}
# {'label': 'NEGATIVE', 'score': 0.7193726897239685}
# {'label': 'POSITIVE', 'score': 0.9707305431365967}
# {'label': 'NEGATIVE', 'score': 0.9996213912963867}
# {'label': 'NEGATIVE', 'score': 0.9997584223747253}
# {'label': 'NEGATIVE', 'score': 0.9971599578857422}
# {'label': 'NEGATIVE', 'score': 0.9886386394500732}
# {'label': 'NEGATIVE', 'score': 0.9997795224189758}
# {'label': 'NEGATIVE', 'score': 0.9900665283203125}
# {'label': 'NEGATIVE', 'score': 0.9996660947799683}
# {'label': 'NEGATIVE', 'score': 0.999674916267395}
# {'label': 'NEGATIVE', 'score': 0.9994519352912903}
# {'label': 'NEGATIVE', 'score': 0.9988512992858887}
# {'label': 'NEGATIVE', 'score': 0.9982110261917114}
# {'label': 'NEGATIVE', 'score': 0.9990826845169067}
# {'label': 'NEGATIVE', 'score': 0.9373472332954407}
# {'label': 'NEGATIVE', 'score': 0.9990972280502319}
# {'label': 'NEGATIVE', 'score': 0.9911242723464966}
# {'label': 'NEGATIVE', 'score': 0.9994852542877197}
# {'label': 'NEGATIVE', 'score': 0.9926531314849854}
# {'label': 'NEGATIVE', 'score': 0.9987016916275024}
# {'label': 'NEGATIVE', 'score': 0.9996483325958252}
# {'label': 'NEGATIVE', 'score': 0.9929534792900085}
# {'label': 'NEGATIVE', 'score': 0.990772008895874}
# {'label': 'NEGATIVE', 'score': 0.9992265701293945}
# {'label': 'NEGATIVE', 'score': 0.9993308782577515}
# {'label': 'NEGATIVE', 'score': 0.9970914125442505}
# {'label': 'NEGATIVE', 'score': 0.9125606417655945}
# {'label': 'NEGATIVE', 'score': 0.999661922454834}
# {'label': 'NEGATIVE', 'score': 0.8916265368461609}
# {'label': 'NEGATIVE', 'score': 0.99674391746521}
# {'label': 'NEGATIVE', 'score': 0.993841290473938}
# {'label': 'NEGATIVE', 'score': 0.8862734436988831}
# {'label': 'NEGATIVE', 'score': 0.9993062019348145}
# {'label': 'NEGATIVE', 'score': 0.9994378685951233}
# {'label': 'NEGATIVE', 'score': 0.9912583231925964}
# {'label': 'NEGATIVE', 'score': 0.9992488026618958}
# {'label': 'POSITIVE', 'score': 0.9818921685218811}
# {'label': 'NEGATIVE', 'score': 0.99972003698349}
# {'label': 'NEGATIVE', 'score': 0.9993791580200195}
# {'label': 'NEGATIVE', 'score': 0.9977832436561584}
# {'label': 'NEGATIVE', 'score': 0.9997552037239075}
# {'label': 'NEGATIVE', 'score': 0.9997596144676208}
# {'label': 'NEGATIVE', 'score': 0.6152032017707825}
# {'label': 'POSITIVE', 'score': 0.8755884170532227}
# {'label': 'NEGATIVE', 'score': 0.9996525049209595}
# {'label': 'NEGATIVE', 'score': 0.9973737001419067}
# {'label': 'POSITIVE', 'score': 0.9998058676719666}
# {'label': 'NEGATIVE', 'score': 0.9955848455429077}
# {'label': 'NEGATIVE', 'score': 0.9995935559272766}
# {'label': 'NEGATIVE', 'score': 0.992885172367096}
# {'label': 'NEGATIVE', 'score': 0.9329479336738586}
# {'label': 'NEGATIVE', 'score': 0.9994797110557556}
# {'label': 'NEGATIVE', 'score': 0.9913669228553772}
# {'label': 'NEGATIVE', 'score': 0.9993718266487122}
# {'label': 'NEGATIVE', 'score': 0.9963371753692627}
# {'label': 'POSITIVE', 'score': 0.9595882296562195}
# {'label': 'NEGATIVE', 'score': 0.9996942281723022}
# {'label': 'NEGATIVE', 'score': 0.9477343559265137}
# {'label': 'NEGATIVE', 'score': 0.9995530247688293}
# {'label': 'NEGATIVE', 'score': 0.9989522695541382}
# {'label': 'NEGATIVE', 'score': 0.9997050166130066}
# {'label': 'POSITIVE', 'score': 0.9902051687240601}
# {'label': 'NEGATIVE', 'score': 0.9991212487220764}
# {'label': 'NEGATIVE', 'score': 0.9997575879096985}
# {'label': 'NEGATIVE', 'score': 0.9992800354957581}
# {'label': 'NEGATIVE', 'score': 0.9987448453903198}
